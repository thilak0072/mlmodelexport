# %%
import pandas as pd

df = pd.read_csv('Documents/delaney_solubility_with_descriptors.csv')
df
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]

# %%
y = df['logS']
y
# Out:
# 0      -2.180
# 1      -2.000
# 2      -1.740
# 3      -1.480
# 4      -3.040
#         ...
# 1139    1.144
# 1140   -4.925
# 1141   -3.893
# 1142   -3.790
# 1143   -2.581
# Name: logS, Length: 1144, dtype: float64

# %%
X = df.drop('logS', axis=1)
X
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0     2.59540  167.850                0.0            0.000000
# 1     2.37650  133.405                0.0            0.000000
# 2     2.59380  167.850                1.0            0.000000
# 3     2.02890  133.405                1.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# ...       ...      ...                ...                 ...
# 1139  1.98820  287.343                8.0            0.000000
# 1140  3.42130  286.114                2.0            0.333333
# 1141  3.60960  308.333                4.0            0.695652
# 1142  2.56214  354.815                3.0            0.521739
# 1143  2.02164  179.219                1.0            0.461538
#
# [1144 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %%
X_train
# Out:
#      MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 107  3.14280  112.216                5.0            0.000000
# 378 -2.07850  142.070                0.0            0.000000
# 529 -0.47730  168.152                0.0            0.000000
# 546 -0.86740  154.125                0.0            0.000000
# 320  1.62150  100.161                2.0            0.000000
# ..       ...      ...                ...                 ...
# 802  3.00254  250.301                1.0            0.842105
# 53   2.13860   82.146                3.0            0.000000
# 350  5.76304  256.348                0.0            0.900000
# 79   3.89960  186.339               10.0            0.000000
# 792  2.52334  310.297                3.0            0.300000
#
# [915 rows x 4 columns]

# %%
X_test
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 822   2.91000  172.268                7.0            0.000000
# 118   7.27400  360.882                1.0            0.666667
# 347   1.94040  145.161                0.0            0.909091
# 1123  1.98640  119.378                0.0            0.000000
# 924   1.70062  108.140                0.0            0.750000
# ...       ...      ...                ...                 ...
# 1114  1.76210  478.513                4.0            0.000000
# 427   6.32820  276.338                0.0            1.000000
# 711   0.04430  218.205                5.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# 948   3.56010  318.328                2.0            0.750000
#
# [229 rows x 4 columns]

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
y_lr_train_pred = lr.predict(X_train)
y_lr_test_pred = lr.predict(X_test)

# %%
y_lr_train_pred
# Out:
# array([-2.83668969,  0.84208401, -0.50930302, -0.13058053, -1.6269208 ,
#        -2.86103037, -2.32208333, -4.16684323, -5.04235077, -2.29737009,
#        -3.15082845, -4.33037208, -1.43700682, -2.59060064, -7.09025955,
#        -2.32734557, -4.19073421, -2.63904005, -3.58104074, -3.75929058,
#        -2.5501665 , -3.26968347, -2.78911367, -2.69251051, -0.77437547,
#        -6.61955792, -2.99084623, -2.36975061, -7.18167736, -1.52816491,
#        -4.81736265, -0.86996608, -7.09025955, -1.87404275, -2.58013247,
#        -4.80953284, -4.17454084, -1.95444152, -3.50503339, -2.7411418 ,
#        -1.87131835, -2.45270806, -3.07252433, -1.48988982, -3.98778754,
#        -1.35216679, -0.16932277, -6.05237002, -3.29550658,  0.30513174,
#        -3.25501463, -5.31993586, -0.4733928 , -4.79180882, -5.82486323,
#        -2.70343539, -3.70838271, -2.4987341 , -2.12301018, -3.11393974,
#        -2.79842053, -1.38274662, -4.3267103 , -3.57778946, -3.42356884,
# ...

# %%
y_lr_test_pred
# Out:
# array([-3.05722870e+00, -7.77785827e+00, -2.55016650e+00, -2.01523582e+00,
#        -2.06375990e+00, -9.99672215e-01, -5.94603364e-01, -5.53626003e-01,
#        -5.72200956e+00, -3.94006681e+00, -3.95496755e+00, -2.29737009e+00,
#        -1.48980354e+00, -1.48988982e+00, -4.64510806e+00, -1.90396018e+00,
#        -1.51566313e+00, -3.16424605e+00, -3.70863920e+00, -5.58105660e+00,
#        -3.25038467e+00, -5.04235077e+00, -5.69194881e+00, -2.14339849e+00,
#        -4.35689341e+00, -5.03964756e+00, -3.10383618e+00, -4.40286964e+00,
#        -4.21276272e+00,  5.56508349e-01, -1.45537678e+00, -4.41027396e+00,
#        -2.59668773e+00, -1.53336276e+00, -5.55749874e-01, -1.67111795e+00,
#        -2.78163675e+00, -3.15395565e+00, -5.27083361e+00, -1.75321446e+00,
#        -1.53350725e+00, -2.01255666e+00, -6.57559167e+00, -7.89433046e+00,
#        -5.76437127e+00, -4.16422068e+00, -3.43694663e+00,  1.43834212e+00,
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score
lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)
lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print('LR MSE (Train): ', lr_train_mse)
print('LR R2 (Train): ', lr_train_r2)
print('LR MSE (Test): ', lr_test_mse)
print('LR R2 (Test): ', lr_test_r2)
# Out:
# LR MSE (Train):  1.0075362951093687
# LR R2 (Train):  0.7645051774663391
# LR MSE (Test):  1.0206953660861033
# LR R2 (Test):  0.7891616188563282

# %%
lr_results = pd.DataFrame(['Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
lr_results
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression     1.007536    0.764505  1.020695  0.789162

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %%
y_rf_train_pred = rf.predict(X_train)
y_rf_test_pred = rf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)
rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#           Method Training MSE Training R2  Test MSE   Test R2
# 0  Random forest     1.028228    0.759669  1.407688  0.709223

# %%
df_models = pd.concat([lr_results, rf_results], axis=0)

# %%
df_models.reset_index(drop=True)
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression     1.007536    0.764505  1.020695  0.789162
# 1      Random forest     1.028228    0.759669  1.407688  0.709223

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(5,5))
plt.scatter(x=y_train, y=y_lr_train_pred, c="#7CAE00" ,alpha=0.3)
z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)
plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predict LogS')
plt.xlabel('Experimental LogS')
# Out:
# Text(0.5, 0, 'Experimental LogS')

# %%
# Out:
# Training set metrics:
# MSE: 1.01, RMSE: 1.00, R^2: 0.76
#
# Test set metrics:
# MSE: 1.02, RMSE: 1.01, R^2: 0.79
# C:\Users\rajth\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# C:\Users\rajth\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
import warnings
from sklearn.metrics import mean_squared_error
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse_train = mean_squared_error(y_train, y_lr_train_pred)
rmse_train = mean_squared_error(y_train, y_lr_train_pred, squared=False)
r2_train = r2_score(y_train, y_lr_train_pred)
mse_test = mean_squared_error(y_test, y_lr_test_pred)
rmse_test = mean_squared_error(y_test, y_lr_test_pred, squared=False) 
r2_test = r2_score(y_test, y_lr_test_pred)
print("Training set metrics:")
print(f"MSE: {mse_train:.2f}, RMSE: {rmse_train:.2f}, R^2: {r2_train:.2f}")
print("\nTest set metrics:")
print(f"MSE: {mse_test:.2f}, RMSE: {rmse_test:.2f}, R^2: {r2_test:.2f}")
# Out:
# Training set metrics:
# MSE: 1.01, RMSE: 1.00, R^2: 0.76
#
# Test set metrics:
# MSE: 1.02, RMSE: 1.01, R^2: 0.79

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(y_train, y_lr_train_pred, color='blue', label='Actual vs Predicted (Training)')
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], linestyle='--', color='red')
plt.xlabel('Actual logS')
plt.ylabel('Predicted logS')
plt.title('Actual vs Predicted (Training Set)')
plt.legend()
plt.show()

plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_lr_test_pred, color='green', label='Actual vs Predicted (Test)')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='orange')
plt.xlabel('Actual logS')
plt.ylabel('Predicted logS')
plt.title('Actual vs Predicted (Test Set)')
plt.legend()
plt.show()

# %%
hjysry
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 hjysry
#
# NameError: name 'hjysry' is not defined

# %%
import joblib

# Assuming 'model' is your trained model
model = ...  # Your trained model here

# Save the model to a file
joblib.dump(model, 'trained_model.pkl')

print("Model saved as 'trained_model.pkl'")
# Out:
# Model saved as 'trained_model.pkl'

# %%
import joblib

# Assuming 'model' is your trained model
model = ...  # Your trained model here

# Save the model to a file
joblib.dump(model, 'trained_model.pkl')

print("Model saved as 'trained_model.pkl'")
# Out:
# Model saved as 'trained_model.pkl'

# %%
import joblib

# Assuming 'model' is your trained model
model = ...  # Your trained model here

# Save the model to a file
joblib.dump(model, 'trained_model.pkl')

print("Model saved as 'trained_model.pkl'")
# Out:
# Model saved as 'trained_model.pkl'

# %%
import joblib

# Save model
joblib.dump(model, 'model.joblib')

# Load model
model = joblib.load('model.joblib')

# %%
import joblib
joblib.dump(model, 'model.joblib')
model = joblib.load('model.joblib')

# %%
import joblib

# Save model
joblib.dump(model, 'model.joblib')

# Load model
model = joblib.load('model.joblib')

# %%
import joblib

# Save model
joblib.dump(model, 'model_b.joblib')

# Load model
model = joblib.load('model_b.joblib')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 import joblib
#       3 # Save model
# ----> 4 joblib.dump(model, 'model_b.joblib')
#
# NameError: name 'model' is not defined

# %%
print(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(model)
#
# NameError: name 'model' is not defined

# %%
print()

# %%
import joblib

# Assuming 'model' is your trained model
model = ML MODEL BWT.ipynb # Your trained model here

# Save the model to a file
joblib.dump(model, 'trained_model.pkl')

print("Model saved as 'trained_model.pkl'")

# %%
import joblib

# Assuming 'model' is your trained model
model = ML MODEL BWT.ipynb # Your trained model here

# Save the model to a file
joblib.dump(model, 'trained_model.pkl')

print("Model saved as 'trained_model.pkl'")
# Out:
#   Cell In[1], line 4
#     model = ML MODEL BWT.ipynb # Your trained model here
#                ^
# SyntaxError: invalid syntax

# %%
import joblib
model = ml_model_bwt

# Save the model to a file
joblib.dump(model, 'trained_model.joblib')

print("Model saved as 'trained_model.joblib'")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 import joblib
#       3 # Assuming 'model' is your trained model
# ----> 4 model = ml_model_bwt # Your trained model here
#       6 # Save the model to a file
#       7 joblib.dump(model, 'trained_model.joblib')
#
# NameError: name 'ml_model_bwt' is not defined

# %%
pip install fastapi uvicorn
# Out:
# ...
#   Using cached fastapi-0.111.0-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached uvicorn-0.30.1-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached fastapi_cli-0.0.4-py3-none-any.whl.metadata (7.0 kB)
# ...
#   Using cached python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# ...
#      ---------------------------------------- 0.0/51.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/51.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/51.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/51.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/51.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/51.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/51.6 kB ? eta -:--:--
#      --------------- ------------------------ 20.5/51.6 kB ? eta -:--:--
# ...

# %%
import joblib
from fastapi import FastAPI, HTTPException

app = FastAPI()

@app.get("/export-model")
def export_model():
    try:
        model = joblib.load('train_model.pkl') 

        # Export the model or perform any other operations
        # For example, save the model to a file
        joblib.dump(model, 'exported_model.pkl')

        return {"message": "Model exported successfully"}
    except FileNotFoundError:
        raise HTTPException(status_code=500, detail="Model file not found")
    except Exception as e:
        raise HTTPException(status_code=500, detail=f"Error exporting model: {str(e)}")

# %%
from fastapi import FastAPI

app = FastAPI()

@app.get("/")
def read_root():
    return {"Hello": "World"}
# Out:
#   Cell In[4], line 7
#     return {"Hello": "World"}
#                     ^
# SyntaxError: invalid non-printable character U+00A0

# %%
from fastapi import FastAPI

app = FastAPI()

@app.get("/")
def read_root():
    return {"Hello"}

# %%
import uvicorn

if _name_ == "_main_":
    uvicorn.run(app, host="0.0.0.0", port=8000)
# Out:
#   Cell In[6], line 4
#     uvicorn.run(app, host="0.0.0.0", port=8000)
#                                     ^
# SyntaxError: invalid non-printable character U+00A0

# %%
import uvicorn

if __name__ == "_main_":
    uvicorn.run(app,host="0.0.0.0",port=9000)

# %%
import requests

# Define the FastAPI server URL (replace with your actual server URL)
server_url = 'http://localhost:9000'  # Assuming you're running locally on port 8000

# Endpoint to export the model
export_model_endpoint = f"{server_url}/export-model"

# Send GET request to export the model
try:
    response = requests.get(export_model_endpoint)
    response.raise_for_status()  # Raise exception for 4xx or 5xx status codes
    print("Response status code:", response.status_code)
    print("Response body:", response.json())
except requests.exceptions.RequestException as e:
    print("Error:", e)

# %%
import requests

# Define the FastAPI server URL (replace with your actual server URL)
server_url = 'http://localhost:9000'  # Assuming you're running locally on port 8000

# Endpoint to export the model
export_model_endpoint = f"{server_url}/export-model"

# Send GET request to export the model
try:
    response = requests.get(export_model_endpoint)
    response.raise_for_status()  # Raise exception for 4xx or 5xx status codes
    print("Response status code:", response.status_code)
    print("Response body:", response.json())
except requests.exceptions.RequestException as e:
    print("Error:", e)

# %%
import joblib
joblib.dump(lr, 'linear_regression_model.pkl')
joblib.dump(rf, 'random_forest_model.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import joblib
# ----> 2 joblib.dump(lr, 'linear_regression_model.pkl')
#       3 joblib.dump(rf, 'random_forest_model.pkl')
#
# NameError: name 'lr' is not defined

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np
import warnings
import joblib

df = pd.read_csv('delaney_solubility_with_descriptors.csv')
y = df['logS']
X = df.drop('logS', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

lr = LinearRegression()
lr.fit(X_train, y_train)

y_lr_train_pred = lr.predict(X_train)
y_lr_test_pred = lr.predict(X_test)

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)
lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

print('LR MSE (Train): ', lr_train_mse)
print('LR R2 (Train): ', lr_train_r2)
print('LR MSE (Test): ', lr_test_mse)
print('LR R2 (Test): ', lr_test_r2)

joblib.dump(lr, 'linear_regression_model.pkl')

rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(X_train, y_train)

y_rf_train_pred = rf.predict(X_train)
y_rf_test_pred = rf.predict(X_test)

rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)
rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

print('RF MSE (Train): ', rf_train_mse)
print('RF R2 (Train): ', rf_train_r2)
print('RF MSE (Test): ', rf_test_mse)
print('RF R2 (Test): ', rf_test_r2)

joblib.dump(rf, 'random_forest_model.pkl')

lr_results = pd.DataFrame([['Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]], columns=['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2'])
rf_results = pd.DataFrame([['Random forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]], columns=['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2'])
df_models = pd.concat([lr_results, rf_results], axis=0).reset_index(drop=True)
print(df_models)

plt.figure(figsize=(5, 5))
plt.scatter(y_train, y_lr_train_pred, c="#7CAE00", alpha=0.3)
z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)
plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predicted LogS')
plt.xlabel('Experimental LogS')
plt.show()

warnings.filterwarnings("ignore", category=FutureWarning)

mse_train = mean_squared_error(y_train, y_lr_train_pred)
rmse_train = mean_squared_error(y_train, y_lr_train_pred, squared=False)
r2_train = r2_score(y_train, y_lr_train_pred)
mse_test = mean_squared_error(y_test, y_lr_test_pred)
rmse_test = mean_squared_error(y_test, y_lr_test_pred, squared=False)
r2_test = r2_score(y_test, y_lr_test_pred)

print("Training set metrics:")
print(f"MSE: {mse_train:.2f}, RMSE: {rmse_train:.2f}, R^2: {r2_train:.2f}")
print("\nTest set metrics:")
print(f"MSE: {mse_test:.2f}, RMSE: {rmse_test:.2f}, R^2: {r2_test:.2f}")

plt.figure(figsize=(8, 6))
plt.scatter(y_train, y_lr_train_pred, color='blue', label='Actual vs Predicted (Training)')
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], linestyle='--', color='red')
plt.xlabel('Actual logS')
plt.ylabel('Predicted logS')
plt.title('Actual vs Predicted (Training Set)')
plt.legend()
plt.show()

plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_lr_test_pred, color='green', label='Actual vs Predicted (Test)')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='orange')
plt.xlabel('Actual logS')
plt.ylabel('Predicted logS')
plt.title('Actual vs Predicted (Test Set)')
plt.legend()
plt.show()
# Out:
# LR MSE (Train):  1.0075362951093687
# LR R2 (Train):  0.7645051774663391
# LR MSE (Test):  1.0206953660861033
# LR R2 (Test):  0.7891616188563282
# RF MSE (Train):  1.028227802112806
# RF R2 (Train):  0.7596688824431413
# RF MSE (Test):  1.407688264904896
# RF R2 (Test):  0.7092230211002489
#               Method  Training MSE  Training R2  Test MSE   Test R2
# 0  Linear regression      1.007536     0.764505  1.020695  0.789162
# 1      Random forest      1.028228     0.759669  1.407688  0.709223
# Training set metrics:
# MSE: 1.01, RMSE: 1.00, R^2: 0.76
#
# Test set metrics:
# MSE: 1.02, RMSE: 1.01, R^2: 0.79
